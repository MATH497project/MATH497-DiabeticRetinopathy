# %% [markdown]
# # ICO Data object example

# %%
import ICO
import os
import pandas as pd

# %% [markdown]
# The `Data` object is initialized with the path to the directory of .pickle files. On creation it reads in the pickle files, but does not transform the data.

# %%
data = ICO.Data(os.getcwd()+'/ICO_data/')

# %% [markdown]
# The `data` object can be accessed like a dictionary to the underlying `Dataframes`. These will be transformed on their first access into a normalized form. (This might take awhile for the first access)

# %%
encounter_data = data["all_encounter_data"]
encounter_data.head()
# Out:
#                                                 Enc_Date  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a 2014-11-12 13:01:04
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f 2013-06-13 05:15:00
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf 2015-05-26 14:00:00
# 000512b7-21fe-9b74-b94e-ed830cd482aa 2015-11-13 21:45:00
# 00057a51-7334-121d-6bab-7c656db2c674 2012-11-15 20:30:00
#
#                                                                  Person_ID  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a  c6f6f586-5949-33be-6ba9-4e15bab66517
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f  622f0f1e-2f37-b6d0-b8cb-27233eeed792
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf  8c3a8c3e-fa01-dc91-0b1a-6c287ad7b65a
# 000512b7-21fe-9b74-b94e-ed830cd482aa  f35df3cf-3e0c-8a2a-1c1a-de3f54b37d4d
# 00057a51-7334-121d-6bab-7c656db2c674  18368dc2-a09e-4a9b-9cf1-ebd8ee54e06a
#
#                                       Person_Nbr                Primary_Payer  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a      423962  Blue Shield Of Illinois PPO
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f      771595    Adv Humana Health Centers
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf     1033257            Cigna HS MMP/MMAI
# 000512b7-21fe-9b74-b94e-ed830cd482aa     1021950                     Medicare
# 00057a51-7334-121d-6bab-7c656db2c674      316145                 Medicaid HFS
#
#                                                 Smoking_Status MR_OD_SPH  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a                       NaN       NaN
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f              Never smoker       NaN
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf              Never Smoker       NaN
# 000512b7-21fe-9b74-b94e-ed830cd482aa  Current every day smoker        PL
# 00057a51-7334-121d-6bab-7c656db2c674                       NaN       NaN
#
#                                      MR_OD_CYL MR_OD_AXIS MR_OD_DVA MR_OD_NVA  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a       NaN        NaN       NaN       NaN
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f       NaN        NaN       NaN       NaN
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf       NaN        NaN       NaN       NaN
# 000512b7-21fe-9b74-b94e-ed830cd482aa     -0.75        090     20/20       NaN
# 00057a51-7334-121d-6bab-7c656db2c674       NaN        NaN       NaN       NaN
#
#                                          ...      CYCLO_OS_SPH CYCLO_OS_CYL  \
# Enc_ID                                   ...
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a     ...               NaN          NaN
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f     ...               NaN          NaN
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf     ...               NaN          NaN
# 000512b7-21fe-9b74-b94e-ed830cd482aa     ...               NaN          NaN
# 00057a51-7334-121d-6bab-7c656db2c674     ...               NaN          NaN
#
#                                      CYCLO_OS_AXIS CYCLO_OS_DVA CYCLO_OS_NVA  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a           NaN          NaN          NaN
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f           NaN          NaN          NaN
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf           NaN          NaN          NaN
# 000512b7-21fe-9b74-b94e-ed830cd482aa           NaN          NaN          NaN
# 00057a51-7334-121d-6bab-7c656db2c674           NaN          NaN          NaN
#
#                                      A1C    BMI Glucose BP_Systolic  \
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a NaN    NaN     NaN         NaN
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f NaN  22.89     NaN       142.0
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf NaN    NaN     NaN         NaN
# 000512b7-21fe-9b74-b94e-ed830cd482aa NaN    NaN   230.0       103.0
# 00057a51-7334-121d-6bab-7c656db2c674 NaN    NaN     NaN         NaN
#
#                                      BP_Diastolic
# Enc_ID
# 00003ecb-26da-ee4c-98cb-e3d5b580c08a          NaN
# 00026723-3d1c-b59a-6bf8-d43cdb6a0c2f         70.0
# 00049b0e-1ff9-0de9-e6b7-e7dbe9368faf          NaN
# 000512b7-21fe-9b74-b94e-ed830cd482aa         61.0
# 00057a51-7334-121d-6bab-7c656db2c674          NaN
#
# [5 rows x 40 columns]
