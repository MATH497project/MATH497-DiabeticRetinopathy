# %%
# %matplotlib inline 
import pandas as pd
from pprint import pprint
import json
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.width', 1000)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
path = 'E:\\anil\\IIT Sop\\Term02\\MATH497\\ICO_data\\original_pickle\\'
combined_data_df = pd.read_pickle(path+'20170226_ICO_Data_combined.pickle')

# %%
# chicago census data: race distribution
census_data = {'White':77.1,
# 'White, not Hispanic or Latino':61.6,
# 'Hispanic or Latino':17.6,
'Black or African American':13.3,
'Asian':5.6,
'Two or More Races':2.6,
'American Indian or Alaska Native':1.2,
'Native Hawaiian and Other Pacific Islander':0.2}

census_df = pd.DataFrame(census_data.items(), columns=['Race','Percentage of Population(US 2015)'])
census_df.sort_values(by='Race', ascending=1, inplace =True)
census_df.set_index(['Race'], inplace =True)
census_df.head()
census_df.plot(kind = 'bar')

# %%
unstd_race_counts = pd.value_counts(combined_data_df['Race'])
unstd_race_counts.sort_index(inplace='True')
unstd_race_counts.plot(kind='bar')

# %%
race_counts = combined_data_df['Race_Std'].value_counts(normalize =True)
race_counts.sort_index(inplace='True')
race_counts.plot(kind='bar')
